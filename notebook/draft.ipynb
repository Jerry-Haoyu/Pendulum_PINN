# %%
import numpy as np

# %%
data = np.load("../data/linear_decrease/data.npy")
theta = data[:, 0]
theta_prime = data[:, 1]

print(theta)
print(theta_prime)
# Out:
# [ 1.57079633  1.57055121  1.56981574 ... -0.66721667 -0.68517792
#  -0.69701355]
# [ 0.         -0.04902329 -0.09806987 ... -2.09368388 -1.49072232
#  -0.87083539]

# %%
import matplotlib.pyplot as plt

plt.plot(np.linspace(0, 1e-1 * len(theta), len(theta)), theta)
